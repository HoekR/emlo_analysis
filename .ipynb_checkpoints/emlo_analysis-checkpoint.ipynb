# %% [markdown]
# # Data Scopes at a scale: Analyzing EMLO
#
#
# For the Data Scopes at a scale article we wanted a dataset to analyze on different scales. A collection of letters seemed a good choice as
#
# - letters are objects more or less familiar to most humanities scholars
# - letters can be studied at many different scales: a single letter is as much a viable object of study as a large collection of letters and anything in between
#
# We opted for the Early Modern Letters Online (http://emlo.bodleian.ox.ac.uk) collection compiled by the Oxford Bodleian Library in cooperation with a host of other institutes. At the time of writing (March 2020) it contains 51 collections covering both the diplomatic and the scientific and cultural world and spans more than three centuries, with the first letter from 1506 and the last from 1837.
#
# The collection is not available for download, so we had to do some web scraping to get the information ready for analysis.

# %%
import pandas as pd

# %% [markdown]
# ## Collection overview
#
# EMLO has an overview page of its collections, with the number of letters.

# %% [markdown]
# the site is dynamic, so we cannot read it directly using pandas, but use request to store it on our desktop.

# %%
import requests

# %%
# so this does not work
#r = requests.get('http://emlo.bodleian.ox.ac.uk/vis/chronology')
#fn = "/data/home/jupyter-rikh/emlo2020/files/emlo_chronology.html"
#with open(fn, 'wb') as outfl:
#    outfl.write(r.content)

# %%
fn = "/data/data_scopes/copied_txt.html"
with open(fn) as flin:
    df = pd.read_html(flin.read())

df = df[0]
# throw out the 'all_catalogs' row with that duplicates the other 

df_unique = df.drop(0)

# %%
df_unique["Total▼▲"].sum()
# Out:
# 111830

# %%
df_unique['percentage'] = df_unique["Total▼▲"]/df_unique["Total▼▲"].sum()*100
df_unique
# Out:
#                                       Catalogue name▼  Year start▼▲  \
# 1                            Andreae, Johann Valentin          1630
# 2                                        Aubrey, John          1636
# 3                                    Barlaeus, Caspar          1615
# 4                                     Baxter, Richard          1657
# 5                                     Beeckman, Isaac          1612
# 6                         Bisterfeld, Johann Heinrich          1624
# 7                                  Bodleian card name          1508
# 8                               Bourignon, Antoinette          1630
# 9                                        Brahe, Tycho          1568
# 10                                 Comenius, Jan Amos          1622
# 11  Czech students in Protestant universities (Hrubý)          1573
# 12                                    Descartes, René          1619
# 13                                  Fermat, Pierre de          1630
# ...

# %%
df_unique["category"] = pd.qcut(df_unique.percentage, q=4, labels = ['q1', 'q2', 'q3', 'q4'])

# %%
df_unique.sort_values(by='percentage', ascending=False)
# Out:
#                                       Catalogue name▼  Year start▼▲  \
# 7                                  Bodleian card name          1508
# 18                                     Groot, Hugo de          1594
# 21                               Huygens, Constantijn          1608
# 19                                    Hartlib, Samuel          1620
# 1                            Andreae, Johann Valentin          1630
# 20                                Huygens, Christiaan          1636
# 23                                Kircher, Athanasius          1629
# 16                            Graffigny, Françoise de          1716
# 26                                      Lhwyd, Edward          1674
# 50                                       Wallis, John          1641
# 29                                    Mersenne, Marin          1617
# 35                   Peiresc, Nicolas-Claude Fabri de          1602
# 49                                     Vossius, Isaac          1632
# ...

# %%
df_unique.sort_values(by='percentage', ascending=False).style.bar(subset=['percentage'], align='mid', color=['#d65f5f'])
# Out:
# <style  type="text/css" >
#     #T_d8258e1e_7323_11ea_92c7_00505692bd3brow0_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_d8258e1e_7323_11ea_92c7_00505692bd3brow1_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 14.8%, transparent 14.8%);
#         }    #T_d8258e1e_7323_11ea_92c7_00505692bd3brow2_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 13.1%, transparent 13.1%);
#         }    #T_d8258e1e_7323_11ea_92c7_00505692bd3brow3_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.7%, transparent 8.7%);
#         }    #T_d8258e1e_7323_11ea_92c7_00505692bd3brow4_col7 {
#             width:  10em;
#              height:  80%;
# ...

# %%
df_unique.loc[df["Catalogue name▼"]=="Bodleian card name"]['Total▼▲']/df_unique['Total▼▲'].sum()
# Out:
# 7    0.486944
# Name: Total▼▲, dtype: float64

# %% [markdown]
# #### Comment and Analysis
#
# According to its homepage (http://emlo.bodleian.ox.ac.uk/home), EMLO contains (at the time of writing in March 2020) 153127 letters in 167593 versions, written or received by 27021 different people. They come in different collections, of which the chronological table (above) lists 49 (50 including the _all collections_ row) that cover 111830 letters, or two thirds of the total number of letters.
#
# There is a big difference in the size of the EMLO collections. The _Bodleian card catalogue_ accounts for almost half of the total number of letters, while the Richard Baxter catalogue represents only 0.007 percent. If we search the whole collection, this means that by sheer numbers it is likely that in any search half of the results is from the _Bodleian card catalogue_.
#
# It is impossible to determine whether there is an overlap between the collections, but it seems likely that there will be at least _some_ overlap. In the case of the catalogue page of _The Royal Society Early Letters_ "Groups of letters from the collection are included in individual editions of correspondences included on EMLO". Some collections have also been published elsewhere. EMLO is a metadata collection; if there are full text publications of the letters elsewhere, they are referred to from the individual letters.
#
# The provenance of the correspondences is accounted for on the homepage of the respective catalogues; the provenance of single letters is (as far as I have seen) included with each letter as far as it is in the original catalogue. Most of the correspondences are either taken from earlier book publications or are part of a larger archive. Selection criteria for inclusion differ from collection to collection.
# The same is the case for the metadata of the letters. This also has its consequences for the search function of EMLO, especially for the general search. With all letters, there is a sender and a recipient  and a date (as far as known). There are different jump pages for people and places and we may search for chronology.
# We do not know whether we search the total 167593 letters the homepage mentions, or the 111830 letters in the collection overview. Extensive search (http://emlo.bodleian.ox.ac.uk/advanced) allows us to search not only names but also 'Titles, roles or occupations', but this is not complete due to the diverging metadata. For instance, Dutch _raadpensionaris_ Heisius has some letters in the collected catalogues (especially in the _Bodleian card catalogue_), but will not be found when searching on the role 'politician'. Searching on people's names depends on the language names were written in. For instance, searching on 'oranje' or 'orange' yield slightly different results: searching for oranje yields Stuart, Mary (Princess Royal and Princess of Orange), 1631-1660 as a recipient for 30 letters when searching for 'oranje' and 50 letters when searching for 'orange'.

# %%
111830/167593
# Out:
# 0.6672713060808029

# %%
# use the exported csv below
#import string
#dfs = {}
#for letter in string.ascii_lowercase:
#    dfs[letter] = pd.read_html("http://emlo.bodleian.ox.ac.uk/browse/people?letter=%s" % letter)

# %% [raw]
# dfss = { }
# for l in dfs.keys():
#     try:
#         dfss[l] = dfs[l][0]
#     except TypeError:
#         print (dfs[l][0])

# %% [raw]
# aldf = pd.concat(dfss)

# %%
#aldf.to_csv("/data/data_scopes/all_writers.csv")

aldf = pd.read_csv("/data/data_scopes/all_writers.csv")

# %%
written_letters = aldf['Letters Written'].str.replace('-','0').astype('int64')
written_letters.value_counts().plot.line()

# %%
received_letters = aldf['Letters Received'].str.replace('-','0').astype('int64')
received_letters.value_counts().plot.line()

# %%
mentioned_letters = aldf["Letters Mentioning"].str.replace('-','0').astype('int64')
mentioned_letters.value_counts().plot.line()

# %%
wl = written_letters.sum()
rl = received_letters.sum()
ml = mentioned_letters.sum()
print(wl, rl, ml)
# Out:
# 156212 152506 26349

# %% [markdown]
# #### Analysis
#
# From this analysis, it appears that there were approximately as many letters received (152506) as letters written (156212). It is clear that there are many less letters mentioning (26349). This is, obviously, because the 'letters mentioning' category requires mining (or reading) letters for names and this has not been done exhaustively.
#
# Let's look into that in some more details

# %%
received_letters.sort_values(ascending=False).head(20)
# Out:
# 24558    7470
# 11714    4815
# 10544    3795
# 23422    3502
# 10358    3402
# 16494    3355
# 9698     3237
# 13588    3232
# 4511     3072
# 456      2955
# 16281    2821
# 19543    2800
# 6500     2467
# 12630    2210
# 6782     2066
# 3131     1769
# 13732    1743
# 23424    1692
# 20810    1664
# 20722    1637
# Name: Letters Received, dtype: int64

# %%
written_letters.sort_values(ascending=False).head(20)
# Out:
# 9698     4916
# 11714    3963
# 16494    2501
# 9407     2483
# 23422    2312
# 17173    2104
# 11710    1513
# 23600    1512
# 10544    1385
# 17667    1262
# 20722    1114
# 7117     1008
# 10626     960
# 2050      950
# 1490      947
# 19742     933
# 2814      887
# 10079     879
# 15491     860
# 833       856
# Name: Letters Written, dtype: int64

# %%
mentioned_letters.sort_values(ascending=False).head(20)
# Out:
# 15078    682
# 451      251
# 17667    244
# 17455    212
# 12788    204
# 10522    183
# 7117     168
# 18873    157
# 19661    156
# 11940    140
# 19229    127
# 9911     124
# 19903    122
# 9983     122
# 853      120
# 5771     117
# 3864     113
# 16195    105
# 6450     103
# 3031     102
# Name: Letters Mentioning, dtype: int64

# %%
aldf.drop([c for c in aldf.columns if 'Unnamed' in c], axis=1, inplace=True)
aldf["Letters Written"] = written_letters
aldf["Letters Received"] = received_letters
aldf["Letters Mentioning"] = mentioned_letters
aldf
# Out:
#                                                     Name  Letters Written  \
# 0                       Aa, Anthony Willemsz., 1582-1638                0
# 1                               Aalborg, Hans, 1542-1619                0
# 2                          Aa, Pieter van der, 1659-1733               20
# 3                          Aarden, Adriaan van, fl. 1706                0
# 4      Aaron Samuel ben Moses Shalom aus Kremnitz, fl...                0
# ...                                                  ...              ...
# 25090                        Zwinger, Theodor, 1533-1588                0
# 25091                       Zwingli, Huldrych, 1484-1531                0
# 25092                         Zwingli, Ulrich, 1556-1601                2
# 25093                          Zwisler, Johann, fl. 1640                1
# 25094                          Zyll, Otto van, 1588-1656                7
#
#        Letters Received  Letters Mentioning  \
# ...

# %%
aldf.aggregate('sum')
# Out:
# Name                  Aa, Anthony Willemsz., 1582-1638Aalborg, Hans,...
# Letters Written                                                  156212
# Letters Received                                                 152506
# Letters Mentioning                                                26349
# Further details       Gender: maleAlternative names: Aalburgensem, J...
# dtype: object

# %%
# for the distributions see above, but they need some more analysis
# calculated disbalances in the written vs received categories

wisr = aldf.loc[(aldf["Letters Written"] == aldf["Letters Received"])]
wgtr = aldf.loc[(aldf["Letters Written"] > aldf["Letters Received"])]
rgtw = aldf.loc[(aldf["Letters Written"] < aldf["Letters Received"])]
print(len(wisr), len(wgtr), len(rgtw))
# Out:
# 4370 15287 5438

# %% [markdown]
# #### Analysis
#
# Or in words:
#
# - there is a minority of persons with an equal amount of letters received as written
# - there are almost three times as many people who wrote more letters than they received

# %%
# let's look closer at the rows where the number of received letters == the number of written letters
wisr["Letters Written"].value_counts()
# Out:
# 0      3541
# 1       584
# 2       140
# 3        36
# 4        32
# 5        11
# 6         5
# 7         3
# 8         2
# 12        2
# 11        2
# 17        2
# 9         2
# 28        1
# 16        1
# 23        1
# 69        1
# 129       1
# 10        1
# 14        1
# 21        1
# Name: Letters Written, dtype: int64

# %%
#what could those letters with no writer or receiver be?
wisr.loc[wisr["Letters Written"]==0]
# Out:
#                                                     Name  Letters Written  \
# 4      Aaron Samuel ben Moses Shalom aus Kremnitz, fl...                0
# 6                    Abba Gregorius, 1600 or before-1658                0
# 12                                      Abbott, fl. 1802                0
# 15                         Abeele, Jan van den, fl. 1624                0
# 19                             Abelard, Peter, 1079-1142                0
# ...                                                  ...              ...
# 25069                        Zuichemus, Gerbrand, d.1573                0
# 25079                       Zurich, Gaspar van, fl. 1575                0
# 25085                         Zwelfer, Johann, 1618-1668                0
# 25086                         Zwicker, Daniel, 1612-1678                0
# 25091                       Zwingli, Huldrych, 1484-1531                0
#
#        Letters Received  Letters Mentioning  \
# ...

# %% [markdown]
# ah, so this means that there are letters that were probably counted twice. So we would have to compare these numbers with the collections (if that is even possible). We'll look into that later on.

# %%
# but what about the other people with equal numbers of written and received letters
wisr.loc[wisr["Letters Written"]!=0].sort_values(by=["Letters Written"], ascending=False)
# Out:
#                                              Name  Letters Written  \
# 24698                Worthington, John, 1618-1671              129
# 5497                Cotton, John (Sir), 1621-1702               69
# 11966                Janiçon, François, 1634-1705               28
# 19455       Saint-Vincent, Grégoire de, 1584-1667               23
# 1421                   Bathurst, Ralph, 1619-1704               21
# ...                                           ...              ...
# 9453                    Grassi, Orazio, 1583-1654                1
# 9560                   Grelot, Antoine, 1640-1679                1
# 9565                   Grenville, John, 1628-1701                1
# 9580                  Greville, Robert, 1607-1607                1
# 25082  Zuylen van Nyevelt, Aernout van, 1664-1731                1
#
#        Letters Received  Letters Mentioning  \
# 24698               129                  38
# 5497                 69                   0
# ...

# %% [markdown]
# and the number of people with an equal amount of received and written letters is a very small minority. Perhaps their numbers would grow somewhat if the written and received number of letters would not have to be exactly equal, but I see no value in calculating that.

# %%
#and what about the disbalanced rows
#first the received letters for the category where there were more letters written than received
total = wgtr["Letters Received"].value_counts().sum()
print(f'total: {total}\n')
print(wgtr["Letters Received"].value_counts()[0:4])
print(f"""\ntotal {wgtr["Letters Received"].value_counts()[1:4].sum()} or in range 1-4 \n""")
print(wgtr["Letters Received"].value_counts()[5:])
print(f"""\ntotal {wgtr["Letters Received"].value_counts()[5:].sum()} in range 5+ \n""")
# Out:
# total: 15287
#
# 0    12928
# 1      978
# 2      421
# 3      215
# Name: Letters Received, dtype: int64
#
# total 1614 or in range 1-4
#
# 5      90
# 6      50
# 7      49
# 8      47
# 9      34
#        ..
# 198     1
# 214     1
# 125     1
# 170     1
# 743     1
# Name: Letters Received, Length: 106, dtype: int64
#
# total 616 in range 5+

# %% [markdown]
# which means that 84 percent had only written letters and of the 2359 1614 or about two thirds wrote 1-4 letters

# %%
wgtr["Letters Received"].value_counts()[1:].plot.line()

# %%
# and the other way 'round'
total = rgtw["Letters Received"].value_counts().sum()
print(rgtw["Letters Received"].value_counts())
print(f'total: {total}\n')
print(rgtw["Letters Received"].value_counts()[0:4])
print(f"""\ntotal {rgtw["Letters Received"].value_counts()[0:4].sum()} or in range 0-4 \n""")
print(rgtw["Letters Received"].value_counts()[5:])
print(f"""\ntotal {rgtw["Letters Received"].value_counts()[5:].sum()} in range 5+ \n""")
# Out:
# 1       3111
# 2        787
# 3        307
# 4        209
# 5        137
#         ...
# 94         1
# 90         1
# 86         1
# 42         1
# 1743       1
# Name: Letters Received, Length: 213, dtype: int64
# total: 5438
#
# 1    3111
# 2     787
# 3     307
# 4     209
# Name: Letters Received, dtype: int64
#
# total 4414 or in range 0-4
#
# 6       95
# 7       81
# 8       55
# 9       39
# 10      38
#         ..
# 94       1
# 90       1
# 86       1
# 42       1
# 1743     1
# Name: Letters Received, Length: 208, dtype: int64
#
# total 887 in range 5+

# %% [markdown]
# and for the persons who received more letters than they wrote the absolute numbers about one third. Everyone wrote at least one letter. About 80 percent wrote 1-4 letters and 20 percent 5 or more.

# %%
rgtw["Letters Written"].value_counts().plot.line()

# %% [markdown]
# #### Analysis
#
# The persons in EMLO either wrote or received letters, except in a few cases. This probably reflects the archive situation from which the letters come, as correspondences tend to be based on library or archive collections and they typically contain not all letters received.
#
# It is very hard to get an overview over the different collections beyond the number of letters they contain.
